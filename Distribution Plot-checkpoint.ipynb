# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
train=pd.read_csv('C:\\Users\\Windows SSD\\OneDrive\\Desktop\\Develearn\\Plot\\train (2).csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.displot(train['Fare'],bins=10);

# %%
sns.displot(train['Fare'],kde=False,bins=10);

# %%
sns.jointplot(x='Age',y='Fare',data=train,kind='scatter');

# %%
sns.jointplot(x='Age',y='Fare',data=train,kind='hex');

# %%
sns.jointplot(x='Pclass',y='Age',data=train,kind='reg');

# %%
sns.pairplot(train);

# %%
sns.pairplot(train,hue='Sex',palette="icefire");

# %%
sns.rugplot(train['Fare']);

# %%
sns.kdeplot(train['Fare']);
sns.rugplot(train['Fare']);
